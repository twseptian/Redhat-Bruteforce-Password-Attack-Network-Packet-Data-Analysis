# %%
# !tshark -n -r password_redhat-wireshark.pcap -T fields -Eheader=y -e frame.number -e frame.len > frame.len

# %%
# !head -10 frame.len
# Out:
# frame.number	frame.len
# 1	90
# 2	149
# 3	161
# 4	194
# 5	105
# 6	117
# 7	185
# 8	238
# 9	162

# %%
import pandas as pd

# %%
df=pd.read_table("frame.len")

# %%
df
# Out:
#        frame.number  frame.len
# 0                 1         90
# 1                 2        149
# 2                 3        161
# 3                 4        194
# 4                 5        105
# 5                 6        117
# 6                 7        185
# 7                 8        238
# 8                 9        162
# 9                10        238
# 10               11        146
# 11               12        238
# 12               13        146
# 13               14        230
# 14               15        186
# 15               16        178
# 16               17        162
# 17               18         99
# 18               19         93
# 19               20        149
# 20               21        161
# 21               22        194
# 22               23        105
# 23               24        117
# 24               25        185
# 25               26        238
# 26               27        162
# 27               28        254
# 28               29        146
# ...

# %%
df["frame.len"].describe()
# Out:
# count    22406.000000
# mean       124.788405
# std        201.704982
# min         42.000000
# 25%         60.000000
# 50%         62.000000
# 75%        106.000000
# max       1514.000000
# dtype: float64

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
figsize(10,6)

# %%
df["frame.len"].plot(style=".", alpha=0.2)
title("Frame length Password Redhat Wireshark")
ylabel("bytes")
xlabel("frame number")
